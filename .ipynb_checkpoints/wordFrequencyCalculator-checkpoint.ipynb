# %%
import numpy as np
import math as mt

# %%
# def main():
#     words = input("Enter your phrase here: ").split()
#     word_frequencies = {}
#     for word in words:
#         word_frequencies[word] = word_frequencies.get(word, 0) + 1
#     return word_frequencies

# if __name__ == "__main__":
#     main()

# %%
def main():
    
    words = input("Enter your phrase here: ").split()
    
    word_frequencies = {}
    
    for word in words:
        word_frequencies[word] = word_frequencies.get(word, 0) + 1
    
    print(word_frequencies)

if __name__ == "__main__":
    main()
# Out:
# Enter your phrase here:  DSF-FT10 Session - Git Practice - WordFrequencyCalculator
# {'DSF-FT10': 1, 'Session': 1, '-': 2, 'Git': 1, 'Practice': 1, 'WordFrequencyCalculator': 1}
